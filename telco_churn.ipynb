# %%
import pandas as pd
import numpy as  np

# %%
data = pd.read_excel("TelcoChurn\Final_Telco_Customer_Churn_IBM.xlsx")

# %%
data.head()
# Out:
#   Customer ID  Count  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV      1    Male   78       No            Yes      No         No
# 1  7495-OOKFY      1  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY      1    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ      1  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ      1  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents  Count.1  ... Count.3 Quarter.1 Satisfaction Score  \
# 0                     0        1  ...       1        Q3                  3
# 1                     1        1  ...       1        Q3                  3
# 2                     3        1  ...       1        Q3                  2
# 3                     1        1  ...       1        Q3                  2
# 4                     1        1  ...       1        Q3                  2
#
# ...

# %%
print(data.columns)
# Out:
# Index(['Customer ID', 'Count', 'Gender', 'Age', 'Under 30', 'Senior Citizen',
#        'Married', 'Dependents', 'Number of Dependents', 'Count.1', 'Country',
#        'State', 'City', 'Zip Code', 'Lat Long', 'Latitude', 'Longitude',
#        'Count.2', 'Quarter', 'Referred a Friend', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Count.3', 'Quarter.1', 'Satisfaction Score',
# ...

# %%
data.count()
# Out:
# Customer ID                          7043
# Count                                7043
# Gender                               7043
# Age                                  7043
# Under 30                             7043
# Senior Citizen                       7043
# Married                              7043
# Dependents                           7043
# Number of Dependents                 7043
# Count.1                              7043
# Country                              7043
# State                                7043
# City                                 7043
# Zip Code                             7043
# Lat Long                             7043
# Latitude                             7043
# Longitude                            7043
# Count.2                              7043
# Quarter                              7043
# Referred a Friend                    7043
# Number of Referrals                  7043
# Tenure in Months                     7043
# ...

# %%
print(data.isnull().sum())
# Out:
# Customer ID                             0
# Count                                   0
# Gender                                  0
# Age                                     0
# Under 30                                0
# Senior Citizen                          0
# Married                                 0
# Dependents                              0
# Number of Dependents                    0
# Count.1                                 0
# Country                                 0
# State                                   0
# City                                    0
# Zip Code                                0
# Lat Long                                0
# Latitude                                0
# Longitude                               0
# Count.2                                 0
# Quarter                                 0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# ...

# %%
data.tail()
# Out:
#      Customer ID  Count  Gender  Age Under 30 Senior Citizen Married  \
# 7038  2569-WGERO      1  Female   30       No             No      No
# 7039  6840-RESVB      1    Male   38       No             No     Yes
# 7040  2234-XADUH      1  Female   30       No             No     Yes
# 7041  4801-JZAZL      1  Female   32       No             No     Yes
# 7042  3186-AJIEK      1    Male   44       No             No      No
#
#      Dependents  Number of Dependents  Count.1  ... Count.3 Quarter.1  \
# 7038         No                     0        1  ...       1        Q3
# 7039        Yes                     2        1  ...       1        Q3
# 7040        Yes                     2        1  ...       1        Q3
# 7041        Yes                     2        1  ...       1        Q3
# 7042         No                     0        1  ...       1        Q3
#
#      Satisfaction Score  Customer Status Churn Label  Churn Value  \
# ...

# %%
data = data.dropna()

# %%
data.count()
# Out:
# Customer ID                          1869
# Count                                1869
# Gender                               1869
# Age                                  1869
# Under 30                             1869
# Senior Citizen                       1869
# Married                              1869
# Dependents                           1869
# Number of Dependents                 1869
# Count.1                              1869
# Country                              1869
# State                                1869
# City                                 1869
# Zip Code                             1869
# Lat Long                             1869
# Latitude                             1869
# Longitude                            1869
# Count.2                              1869
# Quarter                              1869
# Referred a Friend                    1869
# Number of Referrals                  1869
# Tenure in Months                     1869
# ...

# %%
print(data.shape)
# Out:
# (1869, 56)

# %%
data.tail()
# Out:
#      Customer ID  Count  Gender  Age Under 30 Senior Citizen Married  \
# 2530  5482-NUPNA      1  Female   28      Yes             No      No
# 2531  1122-JWTJW      1    Male   64       No             No     Yes
# 2532  1699-HPSBG      1    Male   44       No             No      No
# 2533  8775-CEBBJ      1  Female   40       No             No      No
# 2534  0639-TSIQW      1  Female   28      Yes             No      No
#
#      Dependents  Number of Dependents  Count.1  ... Count.3 Quarter.1  \
# 2530         No                     0        1  ...       1        Q3
# 2531        Yes                     2        1  ...       1        Q3
# 2532         No                     0        1  ...       1        Q3
# 2533         No                     0        1  ...       1        Q3
# 2534         No                     0        1  ...       1        Q3
#
#      Satisfaction Score  Customer Status Churn Label  Churn Value  \
# ...

# %%
data.dtypes
# Out:
# Customer ID                           object
# Count                                  int64
# Gender                                object
# Age                                    int64
# Under 30                              object
# Senior Citizen                        object
# Married                               object
# Dependents                            object
# Number of Dependents                   int64
# Count.1                                int64
# Country                               object
# State                                 object
# City                                  object
# Zip Code                               int64
# Lat Long                              object
# Latitude                             float64
# Longitude                            float64
# Count.2                                int64
# Quarter                               object
# Referred a Friend                     object
# Number of Referrals                    int64
# ...

# %%
print(data.describe())
# Out:
#         Count          Age  Number of Dependents  Count.1      Zip Code  \
# count  1869.0  1869.000000           1869.000000   1869.0   1869.000000
# mean      1.0    49.735688              0.118245      1.0  93435.752809
# std       0.0    17.604893              0.549902      0.0   1823.231029
# min       1.0    19.000000              0.000000      1.0  90001.000000
# 25%       1.0    35.000000              0.000000      1.0  92117.000000
# 50%       1.0    50.000000              0.000000      1.0  93292.000000
# 75%       1.0    65.000000              0.000000      1.0  95258.000000
# max       1.0    80.000000              7.000000      1.0  96150.000000
#
#           Latitude    Longitude  Count.2  Number of Referrals  \
# count  1869.000000  1869.000000   1869.0          1869.000000
# mean     36.026801  -119.670474      1.0             0.521134
# std       2.497264     2.149758      0.0             1.094667
# min      32.555828  -124.301372      1.0             0.000000
# ...
